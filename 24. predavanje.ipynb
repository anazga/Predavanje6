# %% [markdown]
# # Numerička matematika - 24. predavanje

# %% [markdown]
# ## 1. Nelinearni najmanji kvadrati

# %% [markdown]
# U sljedećem predavanju detaljnije objašnjavamo metodu nelinearnih najmanjih kvadrata

# %%
from IPython.lib.display import YouTubeVideo
vid = YouTubeVideo("BlTiFEj36Wk")
display(vid)
