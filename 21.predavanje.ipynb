# %% [markdown]
# # Numerička matematika - 21. predavanje

# %% [markdown]
# ## 1. Još o rješavanju nelinearnih sustava. Uvod u numeričku optimizaciju

# %% [markdown]
# U sljedećem predavanju kratko opisujemo rješavanje nelinearnih jednadžbi u više dimenzija te dajemo uvod u numeričku optimizaciju

# %%
from IPython.lib.display import YouTubeVideo
vid = YouTubeVideo("x3YXwYfm4Rg")
display(vid)

# %% [markdown]
# ## 2. Primjer nelinearnog sustava

# %% [markdown]
# Sada razmislite kako biste numerički riješili sljedeći diferencijalnu jednadžbu
#
# $$y''(t)=-\sin(y(t))$$
# gdje je
# $$y(0)=0.6\quad y(2\Pi)=0.6$$
#
# te je početno rješenje dano s
#
# $$y^0(t)=0.6\cos t+0.5\sin t$$
# Za diskretizaciju druge derivacije upotrijebiti formulu koju svmo koristili na 4. predavanju i u laboratorijskim vježbama. Napišite sustav koji dobijete za N=5.
# Do sljedećeg predavanja, bit će objavljen video vezano za ovaj problem, te  ćete moći provjeriti vaš postupak.
