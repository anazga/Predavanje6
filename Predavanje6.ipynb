# %% [markdown]
# # Numerička matematika - 6. predavanje

# %% [markdown]
# ## 1.Ponavljanje s prethodnog predavanja

# %% [markdown]
# **Zadatak** Rubni problem
# $$-u''(x)+b(x)u(x)=f(x)$$
# $$u(0)=\alpha, \quad u(1)=\beta$$
# diskretizirajte centralnim diferencijama na ekvidistantnoj mreži, pri čemu je $x_0=0$, $x_6=1$ a funkcije $f$ i $b$ su zadane a $\alpha$ i $\beta$ su poznati skalari.
# Napišite dobiveni linearni sustav. Kojim algoritmom biste takav sustav riješili. Izračunajte $LU$ dekompoziciju matrice sustava za $b(x)=2.$
#
# *Uputa* Za svaki unutarnji čvor u diskretizaciji izmite $b_i=b(x_i)$, a derivacije zamijenite formulama za konačne diferencije.

# %% [markdown]
# ## 2.Interpolacija i aproksimacija funkcija
#
# U prvom dijelu predavanja bavimo se općenito pojmom interpolacije i aproksimacije. Dolazimo do problema loše uvjetovanosti Vandermondeove matrice. Navedeni problem riješiti ćemo promjenom baze prostora u kojem leže interpolacijski polinomi.

# %%
from IPython.lib.display import YouTubeVideo
vid = YouTubeVideo("Xf5PJyeNvts")
display(vid)

# %% [markdown]
# ## 2.1. Lagrangeov interpolacijski polinom

# %% [markdown]
# U ovom predavanju uvodimo Lagrangeovu bazu, i Lagrangeov interpolacijski polinom.
# Problem koji se javlja je oscilatornost interpolacijskih polinoma za veliki broj točaka na rubovima intervala.

# %%
from IPython.lib.display import YouTubeVideo
vid = YouTubeVideo("ULtpBb6zW2E") 
display(vid)

# %% [markdown]
# # 2.2. Ocjena pogreške interpolacije
# U ovom dijelu predavanja procjenjujemo pogrešku koju radimo koristeći interpolacijski polinom. Uočavamo da pažljivo odabranim interpolacijskim točkama možemo smanjiti pogrešku interpolacije. No, na žalost u praksi često ne biramo točke u kojima se provode određena mjerenja, pa često izbor interpolacijskih čvorova nije na nama. Stoga moramo biti svjesni da kod velikog broja točaka možemo dobiti izrazito lošu aproksimaciju neke fizikalne veličine u rubovima intervala.

# %%
from IPython.lib.display import YouTubeVideo
vid = YouTubeVideo("ufM97WyDoNI") 
display(vid)
